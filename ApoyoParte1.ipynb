# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importa el datase apps.csv
ubi =  r"C:\Users\randy\EBAC.PRACTICAS\apps.csv"
# Borra todos los duplicados del dataset
df = pd.read_csv('apps.csv')

# %%
df
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
duplicados = df[df.duplicated()]
print(duplicados)
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df_sin_duplicados = df.drop_duplicates()

# %%
df_sin_duplicados
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9656                             Parkinson Exercices FR              MEDICAL
# 9657                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
print(df_sin_duplicados.shape)
# Out:
# (9659, 13)

# %%
print(df_sin_duplicados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 981.1+ KB
# None

# %%
df_sin_duplicados.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159  19.0      10,000+  Free     0       Everyone
# 1      967  14.0     500,000+  Free     0       Everyone
# 2    87510   8.7   5,000,000+  Free     0       Everyone
# 3   215644  25.0  50,000,000+  Free     0           Teen
# 4      967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # 2

# %%
# Lista de caracteres a eliminar
chars_to_remove = [',', '+', '$']
# Lista de las columnas a limpiar
cols_to_clean = ['Installs', 'Price']

# Loop para cada columna
for col in cols_to_clean:
    # Aplica una función lambda para eliminar los caracteres especiales
    df_sin_duplicados[col] = df_sin_duplicados[col].apply(lambda x: ''.join(c for c in str(x) if c not in chars_to_remove))

# %%
# Lista de caracteres a eliminar
chars_to_remove = [',', '+', '$']
# Lista de las columnas a limpiar
cols_to_clean = ['Installs', 'Price']

# Loop para cada columna
for col in cols_to_clean:
    # Loop para cada caracter especial
    for char in chars_to_remove:
        # Reemplaza el caracter especial por un texto vacío ('')
        df_sin_duplicados[col] = df_sin_duplicados[col].str.replace(char, '', regex=False)

# %%
print(df_sin_duplicados[['Price', 'Installs']])
# Out:
#      Price  Installs
# 0        0     10000
# 1        0    500000
# 2        0   5000000
# 3        0  50000000
# 4        0    100000
# ...    ...       ...
# 9654     0      5000
# 9655     0       100
# 9656     0      1000
# 9657     0      1000
# 9658     0  10000000
#
# [9659 rows x 2 columns]

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   object
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   object
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 981.1+ KB

# %%
# Lista de caracteres a eliminar
chars_to_remove = [',', '+', '$']
# Lista de las columnas a limpiar
cols_to_clean = ['Installs', 'Price']

# Loop para cada columna
for col in cols_to_clean:
    # Loop para cada caracter especial
    for char in chars_to_remove:
        # Reemplaza con una función lambda el caracter especial por un texto vacío ('')
        df_sin_duplicados[col] = df_sin_duplicados[col].apply(lambda x: x.replace('',''))
    # Convierte la columna a tipo flotante (float)
    df_sin_duplicados[col] = df_sin_duplicados[col].astype(float)

# %%
df_sin_duplicados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9659 non-null   object
#  1   Category        9659 non-null   object
#  2   Rating          8196 non-null   float64
#  3   Reviews         9659 non-null   int64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   float64
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9659 non-null   object
#  10  Last Updated    9659 non-null   object
#  11  Current Ver     9651 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 981.1+ KB

# %% [markdown]
# # 3

# %%
num_categories = df_sin_duplicados['Category'].nunique()
print('Number of categories = ', num_categories)
# Out:
# Number of categories =  33

# %%
num_categories = df_sin_duplicados['Category'].nunique()
print('Número de categorías únicas =', num_categories)
# Out:
# Número de categorías únicas = 33

# %%
category_counts = df_sin_duplicados['Category'].value_counts()
print(category_counts)
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   56
# ...

# %%
category_counts.plot(kind='bar', figsize=(12, 6), color='skyblue')
plt.title('Número de aplicaciones por categoría')
plt.xlabel('Categoría')
plt.ylabel('Número de aplicaciones')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 4

# %%
promedio_calificacion = df_sin_duplicados['Rating'].mean()
print('El promedio de calificación de las apps es:', promedio_calificacion)
# Out:
# El promedio de calificación de las apps es: 4.173243045387994

# %%
promedio_por_categoria = df_sin_duplicados.groupby('Category')['Rating'].mean()
print(promedio_por_categoria)
# Out:
# Category
# ART_AND_DESIGN         4.357377
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.344970
# BUSINESS               4.098479
# COMICS                 4.181481
# COMMUNICATION          4.121484
# DATING                 3.970149
# EDUCATION              4.364407
# ENTERTAINMENT          4.135294
# EVENTS                 4.435556
# FAMILY                 4.179664
# FINANCE                4.115563
# FOOD_AND_DRINK         4.172340
# GAME                   4.247368
# HEALTH_AND_FITNESS     4.243033
# HOUSE_AND_HOME         4.150000
# LIBRARIES_AND_DEMO     4.178125
# LIFESTYLE              4.093355
# MAPS_AND_NAVIGATION    4.036441
# MEDICAL                4.166552
# NEWS_AND_MAGAZINES     4.121569
# PARENTING              4.300000
# PERSONALIZATION        4.332215
# PHOTOGRAPHY            4.157414
# PRODUCTIVITY           4.183389
# SHOPPING               4.230000
# SOCIAL                 4.247291
# SPORTS                 4.216154
# ...

# %%
plt.figure(figsize=(10, 6))
df_sin_duplicados['Rating'].dropna().plot(kind='hist', bins=20, color='skyblue', edgecolor='black')
plt.title('Distribución del Rating')
plt.xlabel('Rating')
plt.ylabel('Frecuencia')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 5

# %%
df_filtrado = df_sin_duplicados.dropna(subset=['Rating', 'Size'])
df_filtrado
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9651                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 9652                                      FR Calculator               FAMILY
# 9654                                   Sya9a Maroc - FR               FAMILY
# 9655                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9658      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
large_categories = df_filtrado.groupby('Category').filter(lambda x: len(x) >= 250)

# %%
import seaborn as sns

# %%
# Gráfica size vs. rating
plt1 = sns.jointplot(x = large_categories['Size'], y = large_categories['Rating'])
plt1.fig.suptitle('Tamaño vs. Rating', y=1.02)
# Out:
# Text(0.5, 1.02, 'Tamaño vs. Rating')

# %%
paid_apps = df_sin_duplicados[df_sin_duplicados['Type'] == 'Paid']

# %%
# Gráfica price vs. rating de las aplicaciones de paga
plt2 = sns.jointplot(x=paid_apps['Price'], y=paid_apps['Rating'])
plt2.fig.suptitle('Precio vs. Rating de Aplicaciones de Paga', y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

# Lista de categorías populares
popular_app_cats = df_sin_duplicados[df_sin_duplicados.Category.isin(['GAME', 'FAMILY', 'PHOTOGRAPHY',
                                            'MEDICAL', 'TOOLS', 'FINANCE',
                                            'LIFESTYLE','BUSINESS'])]

# Examina la tendencia de precio graficando el Precio por Categoría
ax = sns.stripplot(x = popular_app_cats['Category'], y = popular_app_cats['Price'], jitter=True, linewidth=1)
ax.set_title('App pricing trend across categories')
# Out:
# Text(0.5, 1.0, 'App pricing trend across categories')

# %%
apps_above_200 = df_sin_duplicados[df_sin_duplicados['Price'] > 200]
apps_above_200[['Category', 'App', 'Price']]
# Out:
#        Category                                App   Price
# 3327     FAMILY             most expensive app (H)  399.99
# 3465  LIFESTYLE                         💎 I'm rich  399.99
# 3469  LIFESTYLE           I'm Rich - Trump Edition  400.00
# 4396  LIFESTYLE                          I am rich  399.99
# 4398     FAMILY                     I am Rich Plus  399.99
# 4399  LIFESTYLE                      I am rich VIP  299.99
# 4400    FINANCE                  I Am Rich Premium  399.99
# 4401  LIFESTYLE                I am extremely Rich  379.99
# 4402    FINANCE                         I am Rich!  399.99
# 4403    FINANCE                 I am rich(premium)  399.99
# 4406     FAMILY                      I Am Rich Pro  399.99
# 4408    FINANCE     I am rich (Most expensive app)  399.99
# 4410     FAMILY                          I Am Rich  389.99
# 4413    FINANCE                          I am Rich  399.99
# 4417    FINANCE                 I AM RICH PRO PLUS  399.99
# ...

# %%
# Carga el archivo user_reviews.csv
reviews_df = r"C:\Users\randy\EBAC.PRACTICAS\user_reviews.csv"
reviews_df = pd.read_csv('user_reviews.csv')
reviews_df.head()
# Out:
#                      App                                             Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
# Une los dos DataFrames usando la columna 'App' como clave
merged_reviews = pd.merge(df_sin_duplicados, reviews_df, on='App', how='inner')

# Muestra los primeros registros del DataFrame resultante
merged_reviews.head()
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 1  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 2  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 3  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
# 4  Coloring book moana  ART_AND_DESIGN     3.9      967  14.0  500000.0  Free
#
#    Price Content Rating                     Genres      Last Updated  \
# 0    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 3    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 4    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# ...

# %%
# Elimina los valores nulos (NA) de las columnas Sentiment y Review
merged_reviews = merged_reviews.dropna(subset=['Sentiment', 'Review'])

# %%
ax = sns.boxplot(x='Type', y='Sentiment_Polarity', data=merged_reviews)
ax.set_title('Sentiment Polarity Distribution')
# Out:
# Text(0.5, 1.0, 'Sentiment Polarity Distribution')
